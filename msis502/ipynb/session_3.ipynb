# %%
from sklearn.datasets import load_iris
iris = load_iris()
# print(iris.DESCR)
iris_attr = iris.data
species = iris.target
print(iris.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
index = iris_attr[:,1]<2.5
a = iris_attr[index]
print(a)
# Out:
# [[4.5 2.3 1.3 0.3]
#  [5.5 2.3 4.  1.3]
#  [4.9 2.4 3.3 1. ]
#  [5.  2.  3.5 1. ]
#  [6.  2.2 4.  1. ]
#  [6.2 2.2 4.5 1.5]
#  [5.5 2.4 3.8 1.1]
#  [5.5 2.4 3.7 1. ]
#  [6.3 2.3 4.4 1.3]
#  [5.  2.3 3.3 1. ]
#  [6.  2.2 5.  1.5]]

# %%
import numpy as np

# %%
b = np.max(a[:,0])
print(b)
# Out:
# 6.3

# %%
# ========================================
# above are reivews, bellow are new things
# ========================================

# %%
import pandas as pd

# %%
df = pd.read_csv('datas/music.csv')
df # DataFrame
# Out:
#            Artist Genre  Listeners     Plays
# 0  Billie Holiday  Jazz    1300000  27000000
# 1    Jimi Hendrix  Rock    2700000  70000000
# 2     Miles Davis  Jazz    1500000  48000000
# 3             SIA   Pop    2000000  74000000

# %%
df.head()
# Out:
#            Artist Genre  Listeners     Plays
# 0  Billie Holiday  Jazz    1300000  27000000
# 1    Jimi Hendrix  Rock    2700000  70000000
# 2     Miles Davis  Jazz    1500000  48000000
# 3             SIA   Pop    2000000  74000000

# %%
# iloc is by number index

# %%
df.iloc[3]
# Out:
# Artist            SIA
# Genre             Pop
# Listeners     2000000
# Plays        74000000
# Name: 3, dtype: object

# %%
df.iloc[0:2,1:3]
# Out:
#   Genre  Listeners
# 0  Jazz    1300000
# 1  Rock    2700000

# %%
df.iloc[2, :3]
# Out:
# Artist       Miles Davis
# Genre               Jazz
# Listeners        1500000
# Name: 2, dtype: object

# %%
df.iloc[[1,2,3], :3]
# Out:
#          Artist Genre  Listeners
# 1  Jimi Hendrix  Rock    2700000
# 2   Miles Davis  Jazz    1500000
# 3           SIA   Pop    2000000

# %%
# loc is by row or colum name

# %%
df
# Out:
#            Artist Genre  Listeners     Plays
# 0  Billie Holiday  Jazz    1300000  27000000
# 1    Jimi Hendrix  Rock    2700000  70000000
# 2     Miles Davis  Jazz    1500000  48000000
# 3             SIA   Pop    2000000  74000000

# %%
df.loc[3, 'Artist']
# Out:
# 'SIA'

# %%
df.loc[2,['Artist', 'Plays']]
# Out:
# Artist    Miles Davis
# Plays        48000000
# Name: 2, dtype: object

# %%
# index 1,2,3 are show rather than normally just 1,2
# because loc is by 'name', so it keeped row 3
df.loc[1:3,['Artist', 'Plays']]
# Out:
#          Artist     Plays
# 1  Jimi Hendrix  70000000
# 2   Miles Davis  48000000
# 3           SIA  74000000

# %%
# 2.1.3
# Changing the Content of a DataFrame

# %%
df
# Out:
#            Artist Genre  Listeners     Plays
# 0  Billie Holiday  Jazz    1300000  27000000
# 1    Jimi Hendrix  Rock    2700000  70000000
# 2     Miles Davis  Jazz    1500000  48000000
# 3             SIA   Pop    2000000  74000000

# %%
df.loc[3, 'Artist'] = 'Taylor Swift'

# %%
df
# Out:
#            Artist Genre  Listeners     Plays
# 0  Billie Holiday  Jazz    1300000  27000000
# 1    Jimi Hendrix  Rock    2700000  70000000
# 2     Miles Davis  Jazz    1500000  48000000
# 3    Taylor Swift   Pop    2000000  74000000

# %%
# mathmatic computation: element-wise
temp = df.loc[:,'Plays']/1000
temp
# Out:
# 0    27000.0
# 1    70000.0
# 2    48000.0
# 3    74000.0
# Name: Plays, dtype: float64

# %%
# Change the content of an entire colum
df.loc[:,'Plays'] = temp
df
# Out:
#            Artist Genre  Listeners    Plays
# 0  Billie Holiday  Jazz    1300000  27000.0
# 1    Jimi Hendrix  Rock    2700000  70000.0
# 2     Miles Davis  Jazz    1500000  48000.0
# 3    Taylor Swift   Pop    2000000  74000.0

# %%
# add a new colum
df.loc[:,'Individual Plays'] = df.loc[:,'Plays']/df.loc[:,'Listeners']
df
# Out:
#            Artist Genre  Listeners    Plays  Individual Plays
# 0  Billie Holiday  Jazz    1300000  27000.0          0.020769
# 1    Jimi Hendrix  Rock    2700000  70000.0          0.025926
# 2     Miles Davis  Jazz    1500000  48000.0          0.032000
# 3    Taylor Swift   Pop    2000000  74000.0          0.037000

# %%
# change colume name
# df.rename(columns = {'Genre':'Other'})

# %%
# 3 Data Visualization
from matplotlib import pyplot as plt

# %%
x = [1,2,3]
y = [1,4,9]
z = [10,0,5]

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.plot(x,z)

plt.show()

# %%
plt.plot(x,y, "o-", color='b', linewidth=2.5)
plt.plot(x,z, "d--", color='r', linewidth=2.5)

plt.title("Toy example")
plt.xlabel('x')
plt.ylabel('y and z')

plt.legend(['this is y', 'this is z'])

plt.show()

# %%
# 3.1.2 Scatter Plot
# plt.scatter(x,y)  #default 
plt.scatter(x,y, s=80, c='r', marker='>')
plt.show()

# %%
from sklearn.datasets import load_iris
iris = load_iris()
attr = iris.data
print(iris.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
plt.scatter(attr[:,0], attr[:,1], c='g', s=40, marker='^')
plt.title("Iris Dataset")
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
plt.show()
